# %%
import os
from html.parser import HTMLParser
from html.entities import name2codepoint

# %%
class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Start tag:", tag)
        for attr in attrs:
            print("     attr:", attr)

    def handle_endtag(self, tag):
        print("End tag  :", tag)

    def handle_data(self, data):
        print("Data     :", data)

    def handle_comment(self, data):
        print("Comment  :", data)

    def handle_entityref(self, name):
        c = chr(name2codepoint[name])
        print("Named ent:", c)

    def handle_charref(self, name):
        if name.startswith('x'):
            c = chr(int(name[1:], 16))
        else:
            c = chr(int(name))
        print("Num ent  :", c)

    def handle_decl(self, data):
        print("Decl     :", data)

parser = MyHTMLParser()

# %%
parser.feed(TARGET_FILE)
# Out:
# Data     : /Users/macbook/Documents/GitRep/PracticesForEngineers/Practices-for-Engineers/CompaniesPractices/Company12/SecondTask/dataset/1.html

# %% [markdown]
# ### PipeLine

# %%
import bs4
import codecs
import requests
from htmldom import htmldom

# %%
TARGET_FILE = '/Users/macbook/Documents/GitRep/PracticesForEngineers/Practices-for-Engineers/CompaniesPractices/Company12/SecondTask/dataset/1.html'

# read file
html_file = codecs.open(TARGET_FILE, 'r', 'utf-8')
soup = bs4.BeautifulSoup(html_file, "html.parser")

# find RESULT part cause rest is the same for all pages 
attachement = soup.find_all('div', class_='publication_container')

# %%
attachement
# Out:
# [<div class="publication_container"><div class="content-wrapper table-scroll">
#  <div class="scroll-wrapper"><div class="publicationcontent" version="1">
#  <table id="begin_pub">
#  <tr>
#  <td></td>
#  </tr>
#  <tr>
#  <td>
#  <h3 class="z_titel">AHK Grundbesitz GmbH &amp; Co. KG</h3>
#  <h4 class="z_titel">Wildeshausen</h4>
#  <h3 class="l_titel">Jahresabschluss zum 31. Dezember
#          2009</h3>
#  <h3 class="b_teil" id="jp_Bilanz">Bilanz</h3>
#  <table border="0" cellpadding="2" cellspacing="0" class="std_table" width="900">
#  <col/>
#  <col/>
#  <col/>
#  <col/>
#  <tbody>
#  <tr>
#  <td colspan="2" style="text-align:left;">
#  <b>A K T I V A</b>
#  </td>
#  <td style="text-align:left;"></td>
#  <td style="text-align:left;"></td>
#  </tr>
#  <tr bgcolor="#F0F0F0">
#  <td style="text-align:left;"></td>
#  <td style="text-align:left;"></td>
#  <td style="vertical-align:bottom;text-align:right;">
#                Geschäftsjahr</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                Vorjahr</td>
#  </tr>
#  <tr>
#  <td style="text-align:left;"></td>
#  <td style="text-align:left;"></td>
#  <td style="vertical-align:bottom;text-align:right;">
#                Euro</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                Euro</td>
#  </tr>
#  <tr bgcolor="#F0F0F0">
#  <td style="text-align:left;">
#  <b>A.</b>
#  </td>
#  <td style="text-align:left;">
#  <b>Anlagevermögen</b>
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#  </td>
#  </tr>
#  <tr>
#  <td style="text-align:left;">I.</td>
#  <td style="text-align:left;">Sachanlagen</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                490.336,16</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                517.039,16</td>
#  </tr>
#  <tr bgcolor="#F0F0F0">
#  <td style="text-align:left;">
#  <b>B.</b>
#  </td>
#  <td style="text-align:left;">
#  <b>Umlaufvermögen</b>
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#  </td>
#  </tr>
#  <tr>
#  <td style="text-align:left;">I.</td>
#  <td style="text-align:left;">Forderungen und sonstige
#                Vermögensgegenstände</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                14.517,29</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                16.297,73</td>
#  </tr>
#  <tr bgcolor="#F0F0F0">
#  <td style="text-align:left;">II.</td>
#  <td style="text-align:left;">Guthaben bei
#                Kreditinstituten</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                21.869,23</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                8.120,14</td>
#  </tr>
#  <tr>
#  <td style="text-align:left;">
#  <b>C.</b>
#  </td>
#  <td style="text-align:left;">
#  <b>Rechnungsabgrenzungsposten</b>
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#                7.515,14</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                8.014,26</td>
#  </tr>
#  <tr bgcolor="#F0F0F0">
#  <td style="text-align:left;"></td>
#  <td style="text-align:left;"></td>
#  <td style="vertical-align:bottom;text-align:right;">
#                534.237,82</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                549.471,29</td>
#  </tr>
#  <tr>
#  <td colspan="2" style="text-align:left;">
#  <b>P A S S I V A</b>
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#  </td>
#  </tr>
#  <tr bgcolor="#F0F0F0">
#  <td colspan="2" style="text-align:left;"></td>
#  <td style="vertical-align:bottom;text-align:right;">
#                Geschäftsjahr</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                Vorjahr</td>
#  </tr>
#  <tr>
#  <td colspan="2" style="text-align:left;"></td>
#  <td style="vertical-align:bottom;text-align:right;">
#                Euro</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                Euro</td>
#  </tr>
#  <tr bgcolor="#F0F0F0">
#  <td style="text-align:left;">
#  <b>A.</b>
#  </td>
#  <td style="text-align:left;">
#  <b>Eigenkapital</b>
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#  </td>
#  </tr>
#  <tr>
#  <td style="text-align:left;">I.</td>
#  <td style="text-align:left;">Kapitalanteile der
#                Kommanditisten</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                10.000,00</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                10.423,00</td>
#  </tr>
#  <tr bgcolor="#F0F0F0">
#  <td style="text-align:left;">II.</td>
#  <td style="text-align:left;">Rücklagen</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                162.102,33</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                162.102,33</td>
#  </tr>
#  <tr>
#  <td style="text-align:left;">
#  <b>B.</b>
#  </td>
#  <td style="text-align:left;">
#  <b>Sonderposten für
#                  Investitionszuschüsse</b>
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#                14.533,00</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                15.333,00</td>
#  </tr>
#  <tr bgcolor="#F0F0F0">
#  <td style="text-align:left;">
#  <b>C.</b>
#  </td>
#  <td style="text-align:left;">
#  <b>Rückstellungen</b>
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#                14.610,00</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                13.196,00</td>
#  </tr>
#  <tr>
#  <td style="text-align:left;">
#  <b>D.</b>
#  </td>
#  <td style="text-align:left;">
#  <b>Verbindlichkeiten</b>
#  </td>
#  <td style="vertical-align:bottom;text-align:right;">
#                332.992,49</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                348.416,96</td>
#  </tr>
#  <tr bgcolor="#F0F0F0">
#  <td style="text-align:left;"></td>
#  <td style="text-align:left;"></td>
#  <td style="vertical-align:bottom;text-align:right;">
#                534.237,82</td>
#  <td style="vertical-align:bottom;text-align:right;">
#                549.471,29</td>
#  </tr>
#  </tbody>
#  </table>
#  <h3 class="b_teil" id="jp_Anhang">Anhang</h3>
#  <p>
#  <b>A.  Allgemeine Angaben und Erläuterungen zum
#          Jahresabschluss</b></p>
#  <p>I.  Allgemeine Angaben</p>
#  <p>Die AHK Grundbesitz GmbH &amp; Co. KG, Wildeshausen,
#          stellt den Jahresabschluss nach den handelsrechtlichen
#          Vorschriften für kleine Personenhandelsgesellschaften
#          i.S.v. §§ 264a und 267 Abs. 1 HGB auf.</p>
#  <p>II.  Bilanzierungs- und Bewertungsmethoden</p>
#  <p>Die Sachanlagen werden zu Anschaffungs- oder
#          Herstellungskosten und, soweit abnutzbar, vermindert um
#          planmäßige Abschreibungen angesetzt.
#          Planmäßige Abschreibungen auf Sachanlagen werden
#          linear vorgenommen.</p>
#  <p>Die sonstigen Vermögensgegenstände und die
#          liquiden Mittel werden zum Nennwert angesetzt.</p>
#  <p>Die Rückstellungen berücksichtigen alle am
#          Bilanzstichtag erkennbaren Risiken und andere ungewisse
#          Verbindlichkeiten. Rückstellungen für drohende
#          Verluste aus schwebenden Geschäften waren nicht zu
#          bilden.</p>
#  <p>Die Verbindlichkeiten sind mit ihren
#          Rückzahlungsbeträgen angesetzt.</p>
#  <p>
#  <b>B.  Erläuterungen zur Bilanz</b></p>
#  <p>I.        A K T I V
#          A</p>
#  <p>Forderungen und sonstige
#          Vermögensgegenstände</p>
#  <p>Sämtliche Forderungen sind innerhalb eines Jahres
#          fällig.</p>
#  <p>II.       P A S S I V
#          A</p>
#  <p>Verbindlichkeiten</p>
#  <p>Es werden Verbindlichkeiten von insgesamt TEuro 333
#          (Vj.: TEuro 348) ausgewiesen, davon mit einer Restlaufzeit
#          von bis zu einem Jahr TEuro 146 (Vj.: TEuro 67) und mit
#          einer Restlaufzeit von mehr als fünf Jahren TEuro 69
#          (Vj.: TEuro 78).</p>
#  <p>Art und Form der Sicherheiten</p>
#  <p>Die Verbindlichkeiten sind in Höhe von
#          TEuro 152 durch Grundschulden besichert.</p>
#  <p>
#  <b>C.  Sonstige Angaben</b></p>
#  <p>I.        Organe</p>
#  <p>Die Geschäftsführung der AHK Grundbesitz GmbH
#          &amp; Co. KG, Wildeshausen, erfolgt durch die
#          Geschäftsführer der H. Krüger Metallbau
#          GmbH, Wildeshausen:</p>
#  <p>Dipl.-Ingenieur Helmut Hoping, Visbek</p>
#  <p>Kauffrau Nicole Ambrosius, Visbek.</p>
#  <p>Die Geschäftsführer vertreten die Gesellschaft
#          alleine und sind von den Beschränkungen des § 181
#          BGB befreit. Die Geschäftsführer sind
#          hauptberuflich für diese Gesellschaften
#          tätig.</p>
#  <p>
#          II.
#          Komplementärin</p>
#  <p>Persönlich haftender Gesellschafter der AHK
#          Grundbesitz GmbH &amp; Co. KG, Wildes-hausen, ist die
#          H. Krüger Metallbau GmbH, Wildeshausen, mit einem
#          gezeichneten Kapital von Euro 100.000,00.</p>
#  <p>Wildeshausen, 11. Februar 2010</p>
#  <p>gez. Helmut Hoping</p>
#  <p>gez. Nicole Ambrosius</p>
#  <p>
#          ......................................................</p>
#  <p>AHK Grundbesitz GmbH &amp; Co. KG</p>
#  <p>Angabe nach § 328 Abs. 1 Nr. 1 S. 2 HGB:</p>
#  <p>Der Jahresabschluss ist durch Beschluss der
#          Gesellschafterversammlung vom 15. Februar 2010 festgestellt
#          worden.</p>
#  </td>
#  </tr>
#  <tr>
#  <td></td>
#  </tr>
#  </table>
#  </div>
#  </div></div>
#  </div>]
