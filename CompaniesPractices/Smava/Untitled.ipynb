# %%
import pandas as pd

# %%
ls
# Out:
# 2017_02_24_Case_Study_BI_Intern_Analysis_of_loan_offers.xlsx
# 2017_02_24_Case_Study_BI_Intern_Marketing_Conversion.xlsx
# 2019_02_BI_Interns_Challenge.pdf
# Untitled.ipynb

# %%
data = pd.read_excel('2017_02_24_Case_Study_BI_Intern_Analysis_of_loan_offers.xlsx')

# %%
data
# Out:
#                          CASE STUDY - Angebote/Banken  \
# 0                                                 NaN
# 1   Please prepare a short presentation in PowerPo...
# 2                                                   1
# 3                                                   2
# 4                                                   3
# 5                                                   4
# 6                                                 NaN
# 7   Erläuterungen zu den Tabellenblättern als Hilf...
# 8                                                 NaN
# 9                     Tabelle "offer sum per account"
# 10                                             Spalte
# 11                                              a_id1
# 12                                         anmeldetag
# 13                                                age
# 14                                       berufsgruppe
# 15                                          einkommen
# ...
