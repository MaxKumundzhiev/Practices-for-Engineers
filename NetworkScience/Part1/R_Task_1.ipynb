# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
G = nx.MultiDiGraph()

G.add_weighted_edges_from([(96, 97, 1.3),
                          (96, 98, 5.6),
                          (97, 98, 1.6),
                          (97, 99, 6.4),
                          (98, 96, 10.3),
                          (99, 96, 32.7),
                          (99, 97, 11.1),
                          (99, 98, 3.4)])

#Visualization
# fixing the size of the figure 
plt.figure(figsize =(5, 5)) 
  
nx.draw_networkx(G, with_labels = True)
nx.draw_networkx_edge_labels(G, pos=nx.spectral_layout(G));
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
#With weightes 1 and 2 depending increase or decrease

G = nx.MultiDiGraph()

G.add_weighted_edges_from([(96, 97, 1),
                          (96, 98, 1),
                          (97, 98, 1),
                          (97, 99, 1),
                          (98, 96, 2),
                          (99, 96, 2),
                          (99, 97, 2),
                          (99, 98, 2)])


#Visualization
# fixing the size of the figure 
plt.figure(figsize =(8, 5)) 
  
nx.draw_networkx(G, with_labels = True)
nx.draw_networkx_edge_labels(G, pos=nx.spectral_layout(G));
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#Weighted from edjency matrix, whic should be subtracted
final_attributes = {(96, 97) : 1.3,
                    (96, 98) : 5.6,
                    (97, 98) : 1.6,
                    (97, 99) : 6.4,
                    (98, 96) : 10.3,
                    (99, 96) : 32.7,
                    (99, 97) : 11.1,
                    (99, 98) : 3.4}

# %%
initial_attributes = {}
for node1, node2, data in G.edges(data=True):
    initial_attributes[(node1, node2)] = data['weight']

print('Initial: \n', initial_list_of_attributes)
print('\n')
print('Final: \n', final_list_of_attributes)
# Out:
# Initial:
#  {(96, 97): 1, (96, 98): 1, (97, 98): 1, (97, 99): 1, (98, 96): 2, (99, 96): 2, (99, 97): 2, (99, 98): 2}
#
#
# Final:
#  {(96, 97): 1.3, (96, 98): 5.6, (97, 98): 1.6, (97, 99): 6.4, (98, 96): 10.3, (99, 96): 32.7, (99, 97): 11.1, (99, 98): 3.4}

# %%
print(initial_attributes.keys(), final_attributes.keys())
# Out:
# dict_keys([(96, 97), (96, 98), (97, 98), (97, 99), (98, 96), (99, 96), (99, 97), (99, 98)]) dict_keys([(96, 97), (96, 98), (97, 98), (97, 99), (98, 96), (99, 96), (99, 97), (99, 98)])

# %%
#Calculating substraction of different weightes

keys = [keys for keys in initial_attributes.keys()]
values = [initial_attributes[key] - final_attributes[key] for key in keys]
new_attributes = dict(zip(keys,values))

new_attributes
# Out:
# {(96, 97): -0.30000000000000004,
#  (96, 98): -4.6,
#  (97, 98): -0.6000000000000001,
#  (97, 99): -5.4,
#  (98, 96): -8.3,
#  (99, 96): -30.700000000000003,
#  (99, 97): -9.1,
#  (99, 98): -1.4}

# %%
initial_attributes
# Out:
# {(96, 97): 1,
#  (96, 98): 1,
#  (97, 98): 1,
#  (97, 99): 1,
#  (98, 96): 2,
#  (99, 96): 2,
#  (99, 97): 2,
#  (99, 98): 2}

# %%
final_attributes
# Out:
# {(96, 97): 1.3,
#  (96, 98): 5.6,
#  (97, 98): 1.6,
#  (97, 99): 6.4,
#  (98, 96): 10.3,
#  (99, 96): 32.7,
#  (99, 97): 11.1,
#  (99, 98): 3.4}

# %%
new_attributes = ([(96, 97, -0.30000000000000004),
                  (96, 98, -4.6),
                  (97, 98, -0.6000000000000001),
                  (97, 99, -5.4),
                  (98, 96, -8.3),
                  (99, 96, -30.700000000000003),
                  (99, 97, -9.1),
                  (99, 98, -1.4)])

# %%
G = nx.MultiDiGraph()

G.add_weighted_edges_from(new_attributes)


#Visualization
# fixing the size of the figure 
plt.figure(figsize =(8, 5)) 
  
nx.draw_networkx(G, with_labels = True)
nx.draw_networkx_edge_labels(G, pos=nx.spectral_layout(G));
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
